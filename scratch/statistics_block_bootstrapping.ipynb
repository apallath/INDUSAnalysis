# %% [markdown]
# # Bootstrapping for uncertainty quantification
#
# Reference: https://dx.doi.org/10.33011%2Flivecoms.1.1.5067

# %%
import numpy as np
import matplotlib.pyplot as plt

import pymbar
from pymbar import testsystems

from statsmodels.graphics import tsaplots

# %%
A_t = testsystems.correlated_timeseries_example(N=1000, tau=5.0)
plt.plot(A_t)

# %%
tsaplots.plot_acf(A_t); #semicolon suppresses output (double graphs)

# %%
ACF =
# Out:
# 6.482667118166958
